# %%
import pandas_datareader.data as web
import quandl

from datetime import datetime as dt
import json

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %% [markdown]
# # Using `pandas_datareader`

# %%
# Define date range
start = dt(2013,  1, 2)
end   = dt(2019, 12, 2)

# %%
# Get stock prices for FB
fb   = web.DataReader('FB', 'stooq', start, end).sort_index()
goog = web.DataReader('GOOG', 'stooq', start, end).sort_index()
aapl = web.DataReader('AAPL', 'stooq', start, end).sort_index()

# %%
fb.head(), goog.head()
# Out:
# (             Open   High    Low  Close    Volume
#  Date
#  2014-12-04  74.83  75.55  74.66  75.24  14384577
#  2014-12-05  75.80  76.76  75.36  76.36  24289839
#  2014-12-08  76.18  77.25  75.40  76.52  25727714
#  2014-12-09  75.20  76.93  74.78  76.84  25338366
#  2014-12-10  76.65  77.55  76.07  76.18  32185228,
#                Open    High     Low   Close   Volume
#  Date
#  2014-12-04  531.16  537.34  528.59  537.31  1392208
#  2014-12-05  531.00  532.89  524.28  525.26  2557697
#  2014-12-08  527.13  531.00  523.79  526.98  2326833
#  2014-12-09  522.65  534.19  520.50  533.37  1871268
#  2014-12-10  532.96  536.33  525.56  526.06  1716785)

# %%
plt.figure(figsize = (12, 5))
plt.plot(fb.Close, label = 'Facebook')
plt.plot(goog.Close, label = 'Google')
plt.plot(aapl.Close, label = 'Apple')
plt.legend()
plt.title('Closing prices')
plt.plot()
# Out:
# []

# %% [markdown]
# # Using `quandl`

# %%
# Get API key
with open('quandl_api.json', 'r') as f:
    quandl_key = json.load(f)['quandl_key']

# %%
# Get crude oil prices
crude_oil_prices = quandl.get('EIA/PET_RWTC_D')

# %%
crude_oil_prices.head()
# Out:
#             Value
# Date
# 1986-01-02  25.56
# 1986-01-03  26.00
# 1986-01-06  26.53
# 1986-01-07  25.85
# 1986-01-08  25.87

# %%
plt.figure(figsize = (15, 5))
plt.plot(crude_oil_prices)
plt.title('Crude oil prices')
plt.plot()
# Out:
# []

# %%
# Get Apple prices 
aapl = quandl.get('WIKI/AAPL')

# %%
plt.figure(figsize = (12, 5))
plt.plot(aapl.Close, label = 'Apple')
plt.legend()
plt.title('Closing prices')
plt.plot()
# Out:
# []
